# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from konlpy.tag import Okt
okt = Okt()

# %%
row_data = pd.read_json('./melon_arena_train.json', encoding='utf-8')

# %%
row_data = row_data[['plylst_title', 'songs']]

# %%
row_data
# Out:
#                              plylst_title  \
# 0                                 여행같은 음악
# 1                                 요즘 너 말야
# 2                   편하게, 잔잔하게 들을 수 있는 곡.-
# 3                   크리스마스 분위기에 흠뻑 취하고 싶을때
# 4                                추억의 노래 ㅋ
# ...                                   ...
# 115066                      METAL E'SM #2
# 115067     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
# 115068              #1. 눈물이 앞을 가리는 나의_이야기
# 115069  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
# 115070                FAVORITE POPSONG!!!
#
#                                                     songs
# 0       [525514, 129701, 383374, 562083, 297861, 13954...
# 1       [432406, 675945, 497066, 120377, 389529, 24427...
# 2       [83116, 276692, 166267, 186301, 354465, 256598...
# 3       [394031, 195524, 540149, 287984, 440773, 10033...
# 4       [159327, 553610, 5130, 645103, 294435, 100657,...
# ...                                                   ...
# 115066  [429629, 441511, 612106, 516359, 691768, 38714...
# 115067  [321330, 216057, 534472, 240306, 331098, 23288...
# 115068  [50512, 249024, 250608, 371171, 229942, 694943...
# 115069  [533534, 608114, 343608, 417140, 609009, 30217...
# 115070  [26008, 456354, 324105, 89871, 135272, 143548,...
#
# [115071 rows x 2 columns]

# %%
row_data, row_data['plylst_title'], row_data['songs']
# Out:
# (                             plylst_title  \
#  0                                 여행같은 음악
#  1                                 요즘 너 말야
#  2                   편하게, 잔잔하게 들을 수 있는 곡.-
#  3                   크리스마스 분위기에 흠뻑 취하고 싶을때
#  4                                추억의 노래 ㅋ
#  ...                                   ...
#  115066                      METAL E'SM #2
#  115067     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
#  115068              #1. 눈물이 앞을 가리는 나의_이야기
#  115069  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
#  115070                FAVORITE POPSONG!!!
#
#                                                      songs
#  0       [525514, 129701, 383374, 562083, 297861, 13954...
#  1       [432406, 675945, 497066, 120377, 389529, 24427...
#  2       [83116, 276692, 166267, 186301, 354465, 256598...
#  3       [394031, 195524, 540149, 287984, 440773, 10033...
#  4       [159327, 553610, 5130, 645103, 294435, 100657,...
#  ...                                                   ...
#  115066  [429629, 441511, 612106, 516359, 691768, 38714...
#  115067  [321330, 216057, 534472, 240306, 331098, 23288...
#  115068  [50512, 249024, 250608, 371171, 229942, 694943...
#  115069  [533534, 608114, 343608, 417140, 609009, 30217...
#  115070  [26008, 456354, 324105, 89871, 135272, 143548,...
#
#  [115071 rows x 2 columns],
#  0                                   여행같은 음악
#  1                                   요즘 너 말야
#  2                     편하게, 잔잔하게 들을 수 있는 곡.-
#  3                     크리스마스 분위기에 흠뻑 취하고 싶을때
#  4                                  추억의 노래 ㅋ
#                          ...
#  115066                        METAL E'SM #2
#  115067       빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
#  115068                #1. 눈물이 앞을 가리는 나의_이야기
#  115069    퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
#  115070                  FAVORITE POPSONG!!!
#  Name: plylst_title, Length: 115071, dtype: object,
#  0         [525514, 129701, 383374, 562083, 297861, 13954...
#  1         [432406, 675945, 497066, 120377, 389529, 24427...
#  2         [83116, 276692, 166267, 186301, 354465, 256598...
#  3         [394031, 195524, 540149, 287984, 440773, 10033...
#  4         [159327, 553610, 5130, 645103, 294435, 100657,...
#                                  ...
#  115066    [429629, 441511, 612106, 516359, 691768, 38714...
#  115067    [321330, 216057, 534472, 240306, 331098, 23288...
#  115068    [50512, 249024, 250608, 371171, 229942, 694943...
#  115069    [533534, 608114, 343608, 417140, 609009, 30217...
#  115070    [26008, 456354, 324105, 89871, 135272, 143548,...
#  Name: songs, Length: 115071, dtype: object)

# %%
data = row_data.rename({'plylst_title' : 'title'} ,axis = 'columns')
data
# Out:
#                                     title  \
# 0                                 여행같은 음악
# 1                                 요즘 너 말야
# 2                   편하게, 잔잔하게 들을 수 있는 곡.-
# 3                   크리스마스 분위기에 흠뻑 취하고 싶을때
# 4                                추억의 노래 ㅋ
# ...                                   ...
# 115066                      METAL E'SM #2
# 115067     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
# 115068              #1. 눈물이 앞을 가리는 나의_이야기
# 115069  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
# 115070                FAVORITE POPSONG!!!
#
#                                                     songs
# 0       [525514, 129701, 383374, 562083, 297861, 13954...
# 1       [432406, 675945, 497066, 120377, 389529, 24427...
# 2       [83116, 276692, 166267, 186301, 354465, 256598...
# 3       [394031, 195524, 540149, 287984, 440773, 10033...
# 4       [159327, 553610, 5130, 645103, 294435, 100657,...
# ...                                                   ...
# 115066  [429629, 441511, 612106, 516359, 691768, 38714...
# 115067  [321330, 216057, 534472, 240306, 331098, 23288...
# 115068  [50512, 249024, 250608, 371171, 229942, 694943...
# 115069  [533534, 608114, 343608, 417140, 609009, 30217...
# 115070  [26008, 456354, 324105, 89871, 135272, 143548,...
#
# [115071 rows x 2 columns]

# %%
data.iloc[0].keys()
# Out:
# Index(['title', 'songs'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115071 entries, 0 to 115070
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   115071 non-null  object
#  1   songs   115071 non-null  object
# dtypes: object(2)
# memory usage: 1.8+ MB

# %%
# 중복 타이틀인 경우 행 제거
title= []
songs=[]
for i in data['title'].drop_duplicates().index:
    title.append(data['title'].iloc[i])
    songs.append(data['songs'].iloc[i])
_data = pd.DataFrame({'title' : title, 'songs' : songs})

# %%
data = _data
# 중복 제거 결과 : 115071 -> 110531

# %%
i = 7
data['title'].iloc[i], okt.pos(data['title'].iloc[i], stem=True), okt.nouns(data['title'].iloc[i])
# Out:
# ('멍청이.. 내맘도 몰라.',
#  [('멍청이', 'Noun'),
#   ('..', 'Punctuation'),
#   ('내', 'Determiner'),
#   ('맘', 'Noun'),
#   ('도', 'Josa'),
#   ('모르다', 'Verb'),
#   ('.', 'Punctuation')],
#  ['멍청이', '맘'])

# %%
okt.pos('너도 알았으면 하는 20년 3월 노래들	.', stem=True)
# Out:
# [('너', 'Noun'),
#  ('도', 'Josa'),
#  ('알다', 'Verb'),
#  ('하다', 'Verb'),
#  ('20년', 'Number'),
#  ('3월', 'Number'),
#  ('노래', 'Noun'),
#  ('들', 'Suffix'),
#  ('\t', 'Foreign'),
#  ('.', 'Punctuation')]

# %% [markdown]
# 위의 결과를 통해 Adjective와 Noun만 뽑아오면 된다는 사실을 알게 된다

# %%
# 의미 있는 단어만을 위한 불용어 목록
# 장르, 무의미한 단어들을 직접 삽입하시면 됩니다.

# stopwords = [
#     '때',
#     '어디',
#     '이다',
#     '그',
#     '무조건',
#     '노래',
    
# ]

# %%
# 최소한의 불용어 목록

stopwords = [
    '때',
    '어디',
    '이다',
    '그'
]

# %%
PL_to_tokens = []
for i in range(data.shape[0]):
# for i in range(10):
    # tokens : 플레이리스트의 토큰으로 넣을 실질 token
    # row_tokens : 토큰화된 토큰들
    tokens = []
    row_tokens = okt.pos(data.iloc[i]['title'], stem=True)
    
    for token in row_tokens:
#         if ((token[1] != 'Josa') & (token[1] != 'Verb') & (token[1] != 'Suffix') & (token[1] != 'Punctuation') & (token[1] != 'Foreign') ) and token[0] not in stopwords:
        if ((token[1] == 'Noun') | (token[1] == 'Adjective') | (token[1] == 'Alpha')) and token[0] not in stopwords:
            tokens.append(token[0])
    
    # { '플레이리스트 제목 1 ' : 토큰들 1 , ... }
    PL_to_tokens.append(tokens)

# %%
len(PL_to_tokens), PL_to_tokens
# Out:
# (110531,
#  [['여행', '같다', '음악'],
#   ['요즘', '너', '말'],
#   ['편하다', '잔잔하다', '수', '있다', '곡'],
#   ['크리스마스', '분위기', '흠뻑', '취하'],
#   ['추억', '노래'],
#   ['Pop', 'Trend'],
#   ['짝사랑', '고백', '사랑', '이별', '슬픔', '감성', '자극', '곡'],
#   ['멍청이', '맘'],
#   ['DANCING', 'IN', 'THE', 'MOON', 'LIGHT'],
#   ['록', '메탈', 'Written', 'by', '이일우'],
#   ['걸그룹', '땐쓰쏭'],
#   ['노래', '의지', '불', '다짐', 'st', '용', '프로필', '뮤직'],
#   ['너', '위로', '제목', '편지', '준비'],
#   ['트렌디', '그루브', '힙합', '알앤비', 'MUSIC'],
#   ['Autumn', 'in', 'Jazz'],
#   ['게임', '음악'],
#   ['나', '노래'],
#   ['축가', '듀엣'],
#   ['비', '너', '내', '생각'],
#   ['올림픽', '스밍', '목록'],
#   ['조용하다', '맥주', '한잔', '새벽', '감성'],
#   [],
#   ['추억', '명화', '시간', '영화', 'OST', '모음'],
#   ['기분', '좋다', '여름날'],
#   ['하루', '끝', '힐링', '필요하다', '당신', '추천', '곡'],
#   ['새벽', '찬', '바람', '침대', '위', '국외'],
#   ['기분', '좋다', '햇살', '같다', '명곡'],
#   ['사랑스럽다', '남녀', '듀엣'],
#   ['소래'],
#   ['닥힙추', 'Playlist'],
#   ['거슈윈', '스타워즈', '미국', '대표', '클래식'],
#   ['겨울', '미리'],
#   ['아침', '상쾌하다', '빅밴드', '스윙', '스윙'],
#   ['여행가', '길', '음악', '고고씽'],
#   ['하우스', '일렉트로니카', 'POP'],
#   ['프로포즈', '음악'],
#   ['보아', '일본', '곡'],
#   ['다르다', '레깅스', '운동', '시작'],
#   ['발라드', '감성', '발라', '드림', '슬픔', '주의'],
#   ['크리스마스', '캐롤', '모음'],
#   ['것', '위로', '위로', '음악'],
#   ['트렌디', 'Cafe', 'Pop', 'Music'],
#   ['우리나라', '라디오', '명곡'],
#   ['영화', 'Jazz', '를'],
#   ['우울하다', '시크'],
#   ['극도', '우울하다'],
#   ['폭팔', '밴드', 'ROCK', '모음', '집'],
#   ['금쪽', '같다', '휴일', '혼자', '시간', '방해'],
#   ['Electronica', 'lounge', 'Part'],
#   ['살', '여자', '힙합'],
#   ['그루브', '넘치다', '센스', '있다', '음악'],
#   ['나'],
#   ['내', '중화권', '노래'],
#   ['책', '편안하다', '곡'],
#   ['이', '달', '포크'],
#   ['가슴', '시리다', '사랑', '노래'],
#   ['DJ', 'Lime', '유럽', '여행', '팝', '뮤직', 'Vol'],
#   ['사무실', '공기'],
#   ['이별', '후', '당신', '마음', '노래'],
#   ['불타다', '금요일', '저녁', '더욱', '분업', '노래'],
#   ['가을', '카페', 'MUSIC'],
#   ['취향', '저격', '앨범아트'],
#   ['ROCK', '최대한', '듣기', '편하다'],
#   ['여자', '좋아하다', '남자', '노래', '방곡'],
#   ['졸음', '운전', '방지', '댄스댄스', '플레이', '리스트'],
#   ['연애', '세포', '설레다', '뿜뿜', '노래'],
#   ['천상지희', '시간', '순', '명곡', '중', '좋다', '개', '이상'],
#   ['수능시험', '화이팅', '보컬', '곡'],
#   ['퇴근길', '클래식', '이야기'],
#   ['EDM', '서바이벌', '프로그램', '헤드', '라이너', '가지', '논쟁'],
#   ['Mike', 'will', 'made', 'it'],
#   ['도시', '밤', '세련되다', '그루', '브'],
#   ['고속도로', '얼른'],
#   ['이별', '거짓말', '제발'],
#   ['포근하다', '이불', '속', 'R', 'B'],
#   ['날', '가슴'],
#   ['군산대', '쿠바', '클럽', '노래'],
#   ['Lasse', 'Lindh', '베스트'],
#   ['섹시하다', '비트', 'Jarreau', 'Vandal'],
#   ['무게', '다르다', '해외', '헤비메탈', '모음'],
#   ['해변', '드라이브'],
#   ['힐링', '필요하다', '신분', '곡', '곡'],
#   ['크리스마스', '쏭'],
#   ['듣기', '좋다', '뉴에이지'],
#   ['Indie', 'Rock', 'Pops'],
#   ['정열', '라틴음악'],
#   ['기분', '음악', '모음'],
#   ['가을', '밤', '풀', '소리', '뉴에이지'],
#   ['상쾌하다', '아침', '여', '싱그럽다', '뉴에이지', '음악'],
#   ['공통', '감각', 'Italia', 'Caf', 'e'],
#   ['혼자', '밤'],
#   ['언제', '어도', '효과', '만점', '매력', '힙합'],
#   ['있다', '아무', '생각'],
#   ['편견', '금물', '여름', '끝', '니엘', '저스디스', '만남'],
#   ['드라이브', '신나다', '곡'],
#   ['하나', '다른', '곡', '마', '성의', '목소리', '모음'],
#   ['안구', '촉촉하다', '노래'],
#   ['이유', '센치하다', '그렇다', '날', '당신', '픈', '노래'],
#   ['걸그룹', '발라드', '명곡', '모음'],
#   ['노래'],
#   ['잔잔하다', '웅장', '락'],
#   ['감각', '멜로디', '중독', '있다', '비트'],
#   ['악동', '서울', 'DJ', '런쥔', 'NCT', 'DREAM', '추천', '곡'],
#   [],
#   ['벚꽃', '속', '야하다', '봄', '노래'],
#   ['때껄룩', 'TAKE', 'A', 'LOOK', '때껄룩', '사랑', '지상', '최고', '플레이', '리스트'],
#   ['자주', '노래', '목록'],
#   ['밤', '곡'],
#   ['Pop', 'in', 'cafe'],
#   ['퇴근길', '하루', '마무리', '재즈'],
#   ['나', '혼자', '카페', '분위기'],
#   ['휴일', '기분', '전환', '어쿠스틱'],
#   ['센티', '멘탈', '플레이', '리스트', '센치하다', '분위기'],
#   ['어쿠스틱', '부흥', '선도', 'MTV', '언플러그드', '라이브'],
#   ['신해철', '아픔', '없다', '곳'],
#   ['클럽', '걸', '대리', '만족하다'],
#   ['무덥다', '여름', '츠', '노노', '신나다', '상큼', '노래', '시원하다'],
#   ['듣기', '좋다', 'EDM', '추천', '곡'],
#   ['치명', '고도', '치', '정적', '사랑', 'OST'],
#   ['한가지', '음악', '따분하다'],
#   ['폭풍', '드라이브', '운동', '위', '강의', '락', '사운드', '과속', '주의'],
#   ['Dance', '돌', '타이틀곡', '모음'],
#   ['WEEKLY', 'CHOICE', '지금', '주목', '인디뮤직'],
#   ['잠', '안', '자장가'],
#   ['BGM', 'Pop', '영상', '배경음', '매장', '추천', 'Vol'],
#   ['일렉트로닉', '한번', '좋다'],
#   ['매일', '노래'],
#   ['번', '기분', '좋다', '가요'],
#   ['나', '알', '피아노', '곡'],
#   ['감성', '충전', '선율', '아름답다', '피아노', '연주', '곡'],
#   ['흥', '겨', '운', 'J', 'A', 'Z', 'Z'],
#   ['운동', '아드레날린', '폭발'],
#   ['주말', '밤', '푹', '수면', '유도', '음악'],
#   ['Katy', 'perry', '덕후', '랏'],
#   ['JAZZYMOOD'],
#   ['보', '다방', '커피', '향기'],
#   ['앗', '더', '신기하다', '동화'],
#   ['새벽', '위', '노래', '잔잔', '몽환'],
#   ['연애'],
#   ['신나다', '곡'],
#   ['쇼미더머니', '노래', '모음'],
#   ['아침', '활', '위', 'JAZZ'],
#   ['가을', '밤', '니', '그렇다', '밤'],
#   ['가을', '밤', '드라이브', '듣기', '편하다', '곡'],
#   ['기타', '노래', '영국', '뮤지션', 's'],
#   ['멜로디', '포레스트', '캠프', '최종', '라인업'],
#   ['거나', '일단', '신나다', '노래'],
#   ['혼자', '있다'],
#   ['비', '날', '감성', '자극', '듣기', '좋다', '어쿠스틱', '피아노', '발라드'],
#   ['이브', '날', '로맨틱', '멜로디'],
#   ['주말', '도시', '야경', '듣기', '좋다', '노래'],
#   ['오늘', '꿀꿀', '클래식', '음악'],
#   ['밤', '음악'],
#   ['여름', '노래', '멜론', '추천'],
#   [],
#   ['빌보드', 'Hot', 'Singles'],
#   ['가을', '문턱', '나', '감성', '클래식'],
#   ['주말', '힐링', '연주', '곡'],
#   ['가을', '저녁'],
#   ['뚫어뻥', '스트레스', '위대하다', '노래'],
#   ['이별', '후', '더', '슬프다', '감성', '발라드', '노래'],
#   ['취존', '수정'],
#   ['마음껏', '울'],
#   ['귀가', '말랑하다', '인디음악'],
#   ['고음', '병', '당신', '위', '명품', '발라드', '선'],
#   ['MC', '무현', '반한', 'Dope', '외힙'],
#   ['사랑', '연인', 'mood', '잡고'],
#   ['섹', '시', '도', '발', '언니', '노래'],
#   ['빗물', '플레이', '리스트'],
#   ['안녕', '감성', '노래'],
#   ['봄', '설레다', '가득하다', '달달', '음악'],
#   ['음악', '산책', '행복하다', '상상'],
#   ['크리스마스'],
#   ['스쿨', '오브', '힙합', '초', '교시'],
#   ['거짓말', '같다', '이별', '이야기'],
#   ['놀랍다', '주', '은혜'],
#   ['빌보드', 'Hot'],
#   ['힙알못', '소리', '해외'],
#   ['자신감', '충전', '파워워킹', '비트', '좋다', '음악'],
#   ['스', '워십', 'CCM', '은혜'],
#   ['I', 'Love', 'You', 'Pop'],
#   ['기분', '전환', '필요하다', '음악'],
#   ['주말', '마음', '정화', '노래', '가요', '팝송'],
#   ['오직', '기타', '목소리', '감성', '포크'],
#   ['달', '새벽', '잠', '오지', '나'],
#   ['AOA', '민아', '추천', '곡'],
#   ['운동', '중', '힘나다', '빠르다', '댄스', '곡'],
#   ['기분', '좋다', '하루', '시작', '산뜻하다', '재즈'],
#   ['심포닉메탈'],
#   ['정신차리다', '댄스', '무아', '지경', '댄스', '음악'],
#   ['사이다', '청량하다', '톡톡', '노래'],
#   ['나', '성향', '향기'],
#   ['Hipster', 'Must', 'Have', 'Listened', 'this'],
#   ['욕', '정도', '좋다', '해외', '알앤비'],
#   ['클럽', '홀릭', 'DJ', 'FALCON', '내한', '공연'],
#   ['lsos'],
#   ['O', 'S', 'T', '모음', '집'],
#   ['발레', '음악', '클래식', '베스트'],
#   ['겨울', '감성', '비트', '특별하다', '연말'],
#   ['도입', '부', 'Mad', 'Sexy', 'Hiphop', 'Playlist'],
#   ['에너지', '노동요'],
#   ['달달', '귀가', '곡'],
#   ['디제잉', '휘'],
#   ['기분', '우울하다', '땐', '힙', '신나다', '팝송'],
#   ['달리'],
#   ['오늘', '루지', '힘들다', '나', '편안하다', '음악'],
#   ['도시', '바다로', '이', '노래'],
#   ['여름', '명곡', '듣기', '만해', '당장', '시원하다', '여름', '노래'],
#   ['밤', '감성', '팝'],
#   ['운동', '필요하다', '당신', '위', '발레', '음악', '클래식'],
#   ['마지막', '주', '퇴근', '플레이', '리스트'],
#   ['소울', '태', '동기', '대중', '소울', '대표', '뮤지션'],
#   ['SM', '작사', '작사가', '김영후'],
#   ['New', 'Hope', 'Club', '내한', '공연', '예상', '셋', '리스트'],
#   ['호선', '버터플라이'],
#   ['빌보드', '인기', '팝송', '듣기', '해도', '즐겁다'],
#   ['UP', 'AND', 'DANCE'],
#   ['이후', '국내', '힙합', '신', '새롭다', '급부', '뉴', '페이스'],
#   ['삶', '구석', '진', '곳', '이야기', '가사'],
#   [],
#   ['나이테', '같다', '노래'],
#   ['독서', '감미롭다', '연주', '음악'],
#   ['멜로', '군'],
#   ['멜로디', '좋다', '미디움', '템포', '팝', '나른하다', '커피한잔', '필요하다', '플레이', '리스트'],
#   ['몽환', '러버', '감성', 'AM'],
#   ['비', '날', '새벽', '듣기', '좋다', '노래'],
#   ['주말', '해', '힐링', '뮤직'],
#   ['봄', '시티', '팝', '느낌'],
#   ['요즘', '기분', '우울하다'],
#   [],
#   ['후기', '바로크', '기후', '세기'],
#   ['합법'],
#   ['수록', '곡', '반란'],
#   ['가을', '가을', '매장', '음악'],
#   ['NEW', 'INDIE', 'WED', '주간', '발견'],
#   ['라디오'],
#   ['걸', '크러시', '원조', '그룹'],
#   ['po', '내적댄스', 'wer', '팝송', '모음'],
#   ['봄', '따뜻하다', '사랑', '노래'],
#   ['세련되다', '스타일', '요즘', 'Rock', '볼'],
#   ['댄스', '팝', '신나다', '스트레스'],
#   ['미리', '메리', '크리스마스'],
#   ['진짜', '개띵곡', '모음', 'zip'],
#   ['이센스'],
#   ['빌보드', '차트', '위곡', '모음', '집'],
#   ['장르', '퓨쳐', '베이스', '몽롱', '감상', '용', '렉', 'Vol'],
#   ['힘들다', '마음', '편하다', '발라드'],
#   ['가지', '느낌', 'maroon', 'part', '빠르다', '버전'],
#   ['비', '날', '가사', '슬프다', '노래'],
#   ['노래'],
#   ['여름방학'],
#   ['잠', '오지', '밤', '고요한', '방', '안', '노래'],
#   ['우리', '카페', '크리스마스', '캐럴'],
#   ['나', '크레바스'],
#   ['잠', '오지', '오늘', '밤', '노래', '모음'],
#   ['테크노', '음악'],
#   ['빌보드', '선정', '가장', '히트', '곡', '최고', '곡'],
#   ['가을', '듣기', '좋다', '음악', '무엇'],
#   ['쿨하다', '이별', '중'],
#   ['부담', '듣기', '좋다', '인디음악'],
#   ['비트', '좋다', '곡', '흔하다', '팝송', '귀르가즘', '꼬우'],
#   ['시원하다', '바다', '그립다', '오늘'],
#   ['JYJ', '재중', '런칭', '파티', '패션쇼'],
#   ['드라이브', '이', '음악'],
#   ['신나다', '크리스마스', '캐롤', '노래', '준비', '널', '위해'],
#   ['출근길', '학교', '길', '음악'],
#   ['후', '덥다', '지근', '여름밤', '불쾌', '지수', '힐링', '클래식'],
#   ['둠칫둠칫', '듣기', '좋다', '음악'],
#   ['외국펍', '느낌', '음악', 'Vol'],
#   ['엄선', '명곡'],
#   ['Hiphop', 'Life'],
#   ['뷰티', 'Chill', '느낌', '패셔너블', '팝'],
#   [],
#   ['음악', '사랑', '부부', '뮤지션', '대표', '곡'],
#   ['HOT', 'SUMMER', '여름', '추천', '곡', '모음'],
#   ['장르', '불문', '맘', '플레이', '리스트'],
#   ['좋다', '젊다', '힙합'],
#   ['주간', '탄식', '빵', '주', 'th'],
#   ['부모님', '생각', '가사', '모음'],
#   ['나', 'BEST', '효'],
#   ['이브', '콘서트'],
#   ['푸른밤', '플레이', '리스트'],
#   ['미세먼지', '답답하다'],
#   ['내', '저장', '노래'],
#   ['라디오'],
#   ['기분', '노래'],
#   ['밥', '밥'],
#   ['밤잠', '설치다', '당신', '위', '밤', '감성', '노래'],
#   ['겨울', '정취', '수', '있다', '클래식'],
#   ['공부', '집중', '클래식'],
#   ['운동', '욕구', '상승', '클럽', '음악', '트레이닝'],
#   ['달콤하다', '음악', '데이트'],
#   ['포크', '싱어', '송라이터', '리바이', '벌'],
#   ['요즘', '노래'],
#   ['겨울', '조용하다', '새벽', '노래'],
#   ['어둠', '저녁', '발라드'],
#   ['팝씬', '여행', '쿨', '키즈', '위', '안내서'],
#   ['달콤하다', '보사노바'],
#   ['방탄', '타이틀곡', '모음'],
#   ['우리', '아이', '자장가', '모음'],
#   ['길거리', '절대', '안되다', '음악'],
#   ['뉴에이지'],
#   ['Branford', 'Marsalis', '자유롭다', '행보', '이면', '예술'],
#   ['재즈', '최신', '곡', '모음', '집'],
#   ['봄', '소리'],
#   ['아이돌', 'All', 'No', 'GD'],
#   ['가을', '드라이브', '듣기', '좋다', '노래'],
#   ['혼자', '시간'],
#   ['카페', '포근하다', '음악'],
#   ['잔디', '초원', '풀잎', '음', '떼', '구름', '목장'],
#   ['혼자', '듣기', '아깝다', '노래', '감성', 'NO'],
#   ['샤워', '듣기', '적절하다', '노래'],
#   ['감성', '재즈'],
#   ['속', '잔잔하다', '발라드'],
#   ['운동', '에너지', '뿜뿜'],
#   ['나른하다', '주말', '오후', '노래'],
#   ['편안하다', '아침', '팝송'],
#   ['우울하다', '땐', '신나다', '댄스', '곡'],
#   ['MBC', 'FM', 'U', '라디오', '목', '날', '음악'],
#   ['따뜻하다', '어쿠스틱'],
#   ['봄', '듣기', '좋다', '팝송'],
#   ['많다', '사람', '노래'],
#   ['유튜브', '조회', '수로', '핫', '요즘', '것'],
#   ['빌보드', 'Hot', '중', 'Single'],
#   ['위로', 'Ep', '힘들다', '이'],
#   ['잠시', '비', '촉촉하다', '여름', '오후', '음악'],
#   ['버스', '안', '노래'],
#   ['편하다'],
#   ['달달', '여름밤'],
#   ['그냥', '달달'],
#   ['공부', '수면', '위', '백색소음', '편안하다', 'ASMR'],
#   ['아이돌', '컴백', '전쟁', '퀸덤', '곡', '모음'],
#   ['사무실', '플레이', '리스트'],
#   ['도입', '부', '매력', '곡'],
#   ['간지', '녀', '박', '팝', '가요', '모음'],
#   ['둠칫둠칫', '리듬', '저절로', '타지', '팝', '모음'],
#   ['내', '좋아하다', '노래'],
#   ['기쁨'],
#   ['퇴근길', '귓가', '뮤직'],
#   ['핵인', '국내', '힙합', '플레이', '리스트', '업데이트'],
#   ['스티', '비', '원더', '히트', '곡', 'Top'],
#   ['꿀꿀하다', '땐'],
#   ['겨울', '밤하늘', '몽환', '송'],
#   ['카페', '듣기', '좋다', '노래'],
#   ['힘들다', '힘', '노래'],
#   ['발렌타인데이', '누군가'],
#   ['집중', '허전하다'],
#   ['바람', '날', '좋아하다', '너'],
#   ['클럽', '액기스', '드루', '업뎃', '완료'],
#   ['외', '사랑', '짝사랑', '너'],
#   ['머리', '맑다', '부드럽다', '뉴에이지', '피아노', '연주', '곡', '모음'],
#   ['재즈', '최신', '곡', '모음', '집'],
#   ['MUSIC', 'BIBLE', 'PROJECT'],
#   ['팝'],
#   ['러브', '숑'],
#   ['달달', '함', '극치', '플레이', '리스트'],
#   ['몽환', '서정', '노이즈', '미학', '슈게이징'],
#   ['이별', '직후', '검색', '추가'],
#   ['우주소녀', '우정', '만남', '아름답다', '노래', '통'],
#   ['테스트', '플레이'],
#   ['한국', '전통음악', '편견'],
#   ['도입', '부', '노래'],
#   ['편지'],
#   ['가을', '사랑', '쓸쓸하다', '대하'],
#   ['주간', '일렉트로니카', '라디오', '주', '발매', '곡'],
#   ['피아노', '소리', '예쁘다', '노래'],
#   ['신곡', 'Pick'],
#   ['감성', '겨울', '발라드'],
#   ['잔잔하다', '이', '밤', '분위기', '좋다', '발라드'],
#   ['Foreign', 'CLub', 'list'],
#   ['Playlist'],
#   ['우울하다', '더', '우울하다', '노래'],
#   ['Christian', 'Rock', '선'],
#   ['For', 'the', 'lonley', 'ladies', 'over'],
#   ['날씨', '선곡', '좋다', '주말', '카페', '감성', '깊다', '멜로디', '보이스', '라떼'],
#   ['매력', '보이스', '남성', '보컬', '음악'],
#   ['외국', 'HIPHOP', 'RNB'],
#   ['요즘', '노래'],
#   ['올드팝', '연말', '파티'],
#   ['너', '나', '시간'],
#   ['시절', '노래'],
#   ['빌보드', '주년', '기념', '빌보드', '빛', '역대', '싱글', 'TOP'],
#   ['겨울'],
#   ['생각', '정리', '필요하다', '필요하다', '피아노', '연주', '곡'],
#   ['오늘', '추천', '곡'],
#   ['마음', '따뜻하다', '편안하다', '힐링', '재즈'],
#   ['콜라보레이션'],
#   ['조용하다', '카페', '분위기', '있다', '노래', '모음', '집'],
#   ['살', '맞이'],
#   ['인디'],
#   ['기분', '좋다', '달콤하다', '멜로디'],
#   ['있다', '신나다', 'EDM'],
#   ['카페', '듣기', '좋다', '음악', '감성', '가득', '취향', '저격', '피아노', '연주', '곡'],
#   ['곡', '중', '가장', '슬프다', '발라드', '모음'],
#   ['매력', 'Voice', '몽환', 'Sound'],
#   ['운동', '힘드다', 'Pop'],
#   ['크리스마스', '분위기', '물씬', '나', '곡', '집합'],
#   ['GPS', '폰부스', '예습', '곡'],
#   ['급', '외로', '기분', '좋다', '노래'],
#   ['뉴에이지', '피아노', '감성', '시간'],
#   ['눈물', '없다', '수', '없다', '슬픔', '발라드'],
#   ['잠', '새벽', '나', '대신', '이별', '노래'],
#   ['아이', '신나다', '신체', '시간'],
#   ['배경음악', '웅장', 'OST'],
#   ['나른하다', '오후'],
#   ['Sechskies', 'Yellow', 'Note', 'Final', 'In', 'Seoul'],
#   ['주인공', 'ost'],
#   ['밤', '발라드'],
#   ['카페', '책', '나른하다', '피아노', '곡'],
#   ['한번', '노래'],
#   ['최고', '기타리스트', '밴드', '하드록', '헤비메탈', '명곡', '선'],
#   ['선곡', '좋다', '주말', '카페', '달달', '봄', '캐롤', '송'],
#   ['이름', '로큰롤', '명예', '전당', '후보'],
#   ['트렌디', '매장', '듣기', '좋다', '곡'],
#   ['간절', '기', '단풍', '단풍', '가을'],
#   ['절', '노래'],
#   ['어', '두운', '새벽', '새까맣다', '하늘', '그림'],
#   ['Korean', 'Dream'],
#   ['트렌디', 'pop', 'vol'],
#   ['Class', 'Time', 'Wind', 'Instruments'],
#   ['아이돌', '명곡', '아보'],
#   ['빵빵', '야하다', '아이돌', '그룹', '명곡'],
#   ['누군가'],
#   ['Came', 'for', 'me'],
#   ['명상', '독서', '클래식'],
#   ['무더위', '고생', '당신', '청량하다', '비트', '감', '사운드'],
#   ['가사도', '멜로디', '좋다', '국내', '발라드'],
#   ['추억', '노래'],
#   ['명품', '남녀', '듀엣곡', '엄선', '곡', '모음'],
#   ['내', '귀', 'CCM'],
#   ['집중', '향상', '클래식', '사색', '위', '클래식'],
#   ['개강', '기념', '학생증', '제시', '프리', '패스'],
#   ['어린시절', '잠결', '토요명화', '영화', 'OST', '보컬'],
#   ['사랑', '잔잔하다', '경계'],
#   ['감미롭다', '피아노', '선율', '재즈', '곡'],
#   ['둠칫두둠칫', '필요하다', '감각', '팝'],
#   ['설레다', '노래'],
#   ['처음', '온', '손님', '단골', '매장', '음악'],
#   ['비', '날', '감성', '있다'],
#   ['더', '커버', '뮤직', 'Al', 'Green', 'VS', 'Delfonics'],
#   ['카페', '연주', '곡', 'BGM'],
#   ['하루', '마무리', '편안하다', '음악'],
#   ['헤이즈', '모음'],
#   ['누에', '보', '시온', '향기'],
#   ['이소라', '위', '기념', '많다', '청곡', '여기'],
#   ['추억', '발라드'],
#   ['발라드', '솔로'],
#   ['맘', '사심'],
#   ['가을', '밤', '혼자', '생각'],
#   ['감성', '폭발'],
#   ['외로움', '가사', '없다', '연주', '음악', '특선'],
#   ['남녀', '듀엣곡', '아름답다', '곡'],
#   ['북카페', '잔잔하다', '음악'],
#   ['나', '소울'],
#   ['은은하다', '섹시하다', '노래', '잔잔하다', '노래'],
#   ['여름'],
#   ['요즘', '몽환', '음악', '드림팝', '얼터너티브', '락', '신스팝'],
#   ['신나다', '금요일', '우리', '오늘', 'Rap', '해'],
#   ['퇴근길', '다소', '멜랑꼴리', '잠깐'],
#   ['청각', '미각', '신', '맛'],
#   ['명품', '중', '명품', '골든', '발라드'],
#   ['가을', '밤', '듣기', '좋다', '노래'],
#   ['감각', '세련되다', '매장', 'BGM'],
#   ['겨울', '팝'],
#   ['방해', '나', '위', '휴가', '음악'],
#   ['Billboard', 'Hot', '주차'],
#   ['아티스트', '추천', '테스트', '따옴표'],
#   ['헬스장', '운동', '듣기', '좋다', '누구', '신나다', '노래'],
#   ['좋다', '분위', '기갑', '아이돌', '명곡'],
#   ['잔잔', '신나다', '사이', '어딘가'],
#   ['오리', '버전', 'vs', '어쿠스틱', '버전'],
#   ['머리', '맑다', '기분', '좋다', '뉴에이지'],
#   ['Addicted'],
#   ['여름', '밤', '잔디밭'],
#   ['팝송', '중', '몇몇', '좋다', '곡'],
#   ['여름', '시원', '상쾌하다', 'POP'],
#   ['joony'],
#   ['오늘', '혼자', '시간', '필요하다'],
#   ['가을', '여행', '낭만', '재즈'],
#   ['광고음악', '감각', '음악'],
#   ['가을', '밤', '감성', '보컬', '알앤비', '모음'],
#   ['고장', '라디오', '오후'],
#   ['가을동화', '삶', '눈물', '그립다', '음악', 'Newage'],
#   ['연애', '초기', '달달', '설레다', '설레다', '노래'],
#   ['나', '가수', '미리', '듣기'],
#   ['그대'],
#   ['노래', '모음'],
#   ['카푸치노', '음악', '방울'],
#   ['보통'],
#   ['노래'],
#   ['따뜻하다', '커피', '한잔', '음악', '조각'],
#   ['눈', '감고', '힐링', '음악'],
#   ['대신', '이노'],
#   ['뉴욕', '가을', '도시', '낭만'],
#   ['기분', '좋다', '하루', '힘나다', '노래'],
#   ['테스타먼트', '간', '드러머', '환상', '명', '연주'],
#   ['한번', '추천', '곡', '모음', '집'],
#   ['옥타곤', '내한', 'Matisse', 'Sadko', '마티스', '사드', '코'],
#   ['밴드', '음악'],
#   ['너', '선물', '음악', '꽃'],
#   ['코첼라', '페스티벌', '강력하다', '일렉트로닉', '음악', '페스티벌', '수', '있다', '이유'],
#   ['톡톡', '몽환', '곡'],
#   ['남자', '아이돌', '노래', '모음'],
#   ['걸그룹', '발라드', '명곡'],
#   ['가을', '끝', '잔잔하다', '음악', '필요하다', 'jazzy', 'music'],
#   ['드라마', 'OST'],
#   ['조금', '남다르다', '음악', '박자'],
#   ['서울', '재즈', '페스티벌'],
#   ['월요병'],
#   ['어서', '힐링', '곡', '맛집'],
#   ['겨울', '따뜻하다', '손', '난로', '같다', '고막', '남', '여친', '감성', '노래'],
#   ['오후', '피크닉', 'AFTERNOON', 'PICNIC'],
#   ['터보', '종국', '맨'],
#   ['조용필'],
#   ['마음', '정화'],
#   ['무한도전', '위대하다', '유산'],
#   ['드라브하', '조용하다', '강변', '카페', '커피한잔', '잔잔하다', '음악'],
#   ['노래', '재즈', '스탠더드'],
#   ['봄날', '드라이브'],
#   ['산책', '적당하다', '흥나', 'POP'],
#   ['또', '한번', '여름'],
#   ['거리', '노래'],
#   ['쇼미더머니', '프로듀서', '스페셜', '코드', '쿤스트', '팔로알토'],
#   ['니드', '포', '스피드', '엣지', 'OST', 'NEED', 'FOR', 'SPEED', 'EDGE', 'OST'],
#   ['아메리카노', '한잔', '가볍다', '출근길'],
#   ['일요일', '드라이브', '듣기', '좋다', '노래'],
#   ['집', '있다', '집', 'home', 'music'],
#   ['오늘', '추천', '곡'],
#   ['욕조', '욕', '힐링', '음악'],
#   ['절', '곡'],
#   ['센치하다', '딥', '감성', '팝'],
#   ['여름', '여행', '분위기', 'UpUp'],
#   ['익숙하다', 'popsongs'],
#   ['일렉트로니카', '파생', '랩', '음악'],
#   ['날', '좋다', '곡', '재발', '행'],
#   ['클럽', '인트', '플레이', '리스트'],
#   ['흑인', '스멜', '코리안', '뮤직'],
#   ['요즘', '가장', '핫', '렉', '팝', '다가', '아주', '그냥'],
#   ['뉴에이지', '최신', '곡', '모음', '집'],
#   ['갈매기', '공화국'],
#   ['피아노', '첫', '걸음', '바이엘', '연습곡'],
#   ['가수', 'No', 'SS', '의', '베스트'],
#   ['머리', '자기', '좋다', 'part'],
#   ['번', '필수', '팝송', '모음'],
#   ['올해', '록', '앨범', '국내', '국외'],
#   ['매일', '어도', '질리', '스', '테디', '셀러', '같다', '노래'],
#   ['썸', '데이트', '재즈'],
#   ['사랑', '시작', '설레임'],
#   ['여름', '시원하다', '댄스', '음악'],
#   ['달콤하다', '노래'],
#   ['기전', '편안하다', '클래식', '음악'],
#   ['불면증', '특효약', '여름밤', '듣기', '좋다', '노래'],
#   ['조용하다', '혼자', '네엣'],
#   ['Pop', 'Danthology'],
#   ['아련하다', '봄', '봄', '향기', '노래'],
#   ['제', '서울', '재즈', '페스티벌', 'Timetable'],
#   ['발라드', '모음', '공간'],
#   ['것', '대로', '위로', '노래'],
#   ['이별', '시작'],
#   ['차안', '듣기', '좋다', '노래'],
#   ['걸그룹', '여름', '히트', '곡'],
#   ['퇴근길', '플레이', '리스트'],
#   ['독일', '싱글', '차트'],
#   ['다시', '봄', '뭔가', '설레다', '요즘', '감성', '더', '촉촉하다', '노래'],
#   ['새벽', '혼자', '너', '생각'],
#   ['달콤하다', '힙합', '다정하다', '발라드'],
#   ['프레', '시업'],
#   ['피아노', '기타', '어쿠스틱', '음악'],
#   ['멋지다', '가을', '날'],
#   ['Seoul', 'Jazz', 'Festival'],
#   ['주관', '한국', '아이돌', '명곡', '모음', '추천'],
#   ['환상', '케미스트리'],
#   ['SEOUL', 'JAZZ', 'FESTIVAL'],
#   ['친구', '동화'],
#   ['카페', '좋다', '음악'],
#   ['출근길', '활기차다', '노래'],
#   ['봄', '크리스마스', '송'],
#   ['ju', 'jae', 'bum'],
#   ['밤하늘', '별', '수', '듯', '국내', '모던록'],
#   ['래퍼', '감성', '띵곡들'],
#   ['조용조', '용', '방탄소년단'],
#   ['P', 'O', 'P'],
#   ['달달', '노래', '임시', '저장'],
#   ['새벽', '좋다', '감성', '노래', '모음'],
#   ['여자', '아이돌', '히트', '곡', '모음', '걸그룹', '돌', '솔로'],
#   ['국내', '감성', 'R', 'B', '모음'],
#   ['트와이스', '국민', '걸그룹', '블랙', '이드', '필승'],
#   ['이', '주의', 'Hidden', 'Tracks', '마지막', '주'],
#   ['아무로', '나미', 'PAST', 'FUTURE', 'TOUR', 'Set', 'List'],
#   ['커피', '찰떡', '궁합', '알앤비', '힙합'],
#   ['공부', '가볍다', '음악'],
#   ['가을', '노래'],
#   ['똑', '똑', '겨울', '노래', '도착', '닷'],
#   ['이', '노래', '진짜', '섹시하다'],
#   ['어둡다', '푸른', '새벽', '같다', '곡'],
#   ['신나다', '리드미컬하다', '노래', '원하다', '당장', '클릭', 'Pt'],
#   ['카페', '힐링', '노래', '카페', '힐링'],
#   ['노래', '틀'],
#   ['멋쟁이', '취향', '저격', '과', '신나다', '사운드', 'Pt'],
#   ['번', '하루', '동안', '신나다', '노래'],
#   ['숙면', '연애', '세포', '줄', '노래'],
#   ['자기', '전', '듣기', '좋다', '따뜻하다', '목소리'],
#   ['따뜻하다', '봄날', '외출', '위', '얼터너티브', '팝'],
#   ['댓', '크리스마스', '캐롤'],
#   ['달콤', '살벌하다', '썸남썸녀용', '노래'],
#   ['팝스타', '한국어', '패치', '완료', '수시', '업데이트'],
#   ['매장', '마감', '곡'],
#   ['DOPE', 'HIPHOP'],
#   [],
#   ['운동'],
#   ['피아니스트', '명', '모음', '집'],
#   ['U', 'M', 'F', '온', '것', '같다', '느낌', 'EDM'],
#   ['내', '고막', '계속', '달달', '구리', '노래'],
#   ['아무', '일', '없다', '감성', '음악'],
#   ['이', '노랗다', '가을', '냄새'],
#   ['프랑스', '싱글', '차트'],
#   ['어린시절', '추억', '만화영화', '주제곡', '베스트'],
#   ['전', '연인', '달콤하다', '자장가'],
#   ['번', '꼭', '베토벤', '작품'],
#   ['지난', '기억', '누군가'],
#   ['운동', '힙', '느낌', '가득', '감각', '면서', '신나다', '팝'],
#   ['아름답다', '알앤비', '힙합'],
#   ['MTV', 'Europe', 'Music', 'Awards', 'Nominees'],
#   ['걸', '노래'],
#   ['주말', '휴식', '위', '뉴에이지', '피아노', '음악'],
#   ['LINKIN', 'PARK', '비공개', '리스닝', '세션', '후기'],
#   ['한국', '힙합', '단체', '곡'],
#   ['새벽', '감성', '촉촉하다'],
#   ['좋아하다'],
#   ['팬텀', '싱어', 'VS', '곡'],
#   ['방탄소년단'],
#   ['리듬', '마라톤', 'EDM'],
#   ['빌보드', 'Hot', 'Singles'],
#   ['일렉빠', 'EDM', '모음', '집'],
#   ['추천', 'OST'],
#   ['점수', '떠블', '수능', '대박', '응원', '위로', '메시지'],
#   ['노래', 'MR', '모음', '항', '상업', '뎃'],
#   ['Healing', 'Music'],
#   ['Ballad', '무인도', '진짜', '발라드', '명곡'],
#   ['겨울', '공기', '머', '금은', '몽환', '인디뮤직', '선'],
#   ['노창', '울', '진짜', '미치다', '곡'],
#   ['밤', '잔잔하다', '수', '있다', '음악'],
#   ['가사', '공감', '노래'],
#   ['우울함', '나락'],
#   ['중년', '나이트', '댄스', '곡'],
#   ['너', '목소리', 'ost', '번외편'],
#   ['요즘', '어쿠스틱', '발라드'],
#   ['재미', '있다', '피아노', '협주곡'],
#   ['자연', '소리', '심리', '안정', '위해'],
#   ['음악', '디자이너', '취향', '저격', '좋다', '노래', '부'],
#   ['Secret', 'Garden', 'Part'],
#   ['뉴에이지', '좋다', '아침', '어보'],
#   ['청량하다', '시원하다', '노래', '드라이브', '곡', '여름', '다다'],
#   ['give', 'thanks', 'feat', 'CCM'],
#   ['추천', '여름밤', '발라드'],
#   ['겨울', '끝', '봄', '잔잔하다', '산뜻하다', '감성', '팝'],
#   ['소리', '좋다', '노래'],
#   ['여름밤', '선선', '감성', '목소리', '전달', '노래'],
#   ['한국', '노래', '중', '좋다', '노래'],
#   ['요즘', '십대', '노래', 's'],
#   ['노이즈', '공간', '감', '몽롱', '함', '슈게이징'],
#   ['우리', '집', '포근하다', '피아노', '음악'],
#   ['애정', '상징', '플레이', '리스트'],
#   ['내', '안', '감정', '우울함'],
#   ['No', 'JAZZ', 'CAFE', 'IN', 'THE', 'CITY', '재즈'],
#   ['DJ', '열'],
#   ['상큼', '락', '하루'],
#   ['편하다', '수', '있다', 'Vocal', 'Jazz'],
#   ['Just', 'my', 'favorite', 'things'],
#   ['가끔', '발라드'],
#   ['신나다', '유로팝'],
#   ['바람', '야외'],
#   ['신화', '추억'],
#   ['겨울', '따스하다', '어쿠스틱'],
#   ['추천', '곡곡'],
#   ['위', '클리', '초이스', '둘째', '주'],
#   ['감성', '이름', '노래'],
#   [],
#   ['Secret', 'Garden', 'Part'],
#   ['흥', 'EDM'],
#   ['겨울', '감성', '이별', '발라드', '노래방', '선곡'],
#   ['뉴이스트', '최애', '곡'],
#   ['lol', '노래'],
#   ['나', '시각', '청각', 'OST'],
#   ['AOMG', '팬', 'GO'],
#   ['내', 'Revealed', '모음'],
#   ['날', '더', '좋다', '노래'],
#   ['오렌지', '빛', '하늘', '황홀하다', '드라이브', '위', '시티', '팝'],
#   ['알앤비', '금금', '금금'],
#   ['듣기', '좋다', '세기말', '한국', '음악'],
#   ['성장', '중', 'Justin', 'Bieber'],
#   ['감성', '필', '충만', '힙합'],
#   [],
#   ['두둠칫', '흥이', '절로', '음악'],
#   ['이스케이프', '코리아', '차', '라인업', '발표'],
#   ['퇴근길', '따뜻하다', '발라드'],
#   ['클래식', '최신', '곡', '모음', '집'],
#   ['순간', '가볍다', '그루', '브', '노래'],
#   ['당신', '기분', '껏', 'EDM'],
#   ['신나다', '노래'],
#   ['추억', '돋다', '영혼', '있다', '노래'],
#   ['감성', '있다', '과거', '최고', '국내', '국외', '락', '발라드', '모음'],
#   ['클럽', '에덴', '주년', '맞이', 'PARTY'],
#   ['캐', '주얼', '레스토랑'],
#   ['태연', '정규앨범'],
#   ['너', '지금', '뭐'],
#   ['힘', '좀', '볼', '신나다', '국내', '락'],
#   ['자극', '많다', '듣기', '좋다', '피아노', '연주', '곡'],
#   ['혼자', '듣기', '아깝다', '음악', 'pop'],
#   ['부활'],
#   ['개인', '플레이', '리스트'],
#   ['매장', '노래'],
#   ['평생'],
#   ['내', '상반기', 'Jazz', 'Album'],
#   ['무더위', '시원하다', '여름', '가요', '모음'],
#   ['Ost', '띵곡', '모음', '집'],
#   ['알', '사람', '팝'],
#   ['멍'],
#   ['비', '날', '잔잔하다'],
#   ['일본', '노래', '모음'],
#   ['감성', '발라드'],
#   ['라디오'],
#   ['내적댄스', '유발', '곡'],
#   ['소울', '어쿠스틱'],
#   ['Summer', 'time', 'love'],
#   ['뮤직', '테라', '피', '스', '테디'],
#   ['둘이서', '차안', '분위기', '있다', '노래'],
#   ['중복', '비', '무조건', '신나다', '음악'],
#   ['짬', 'Vibe', '세대', '힙합', '래퍼'],
#   ['groovy', '룸', 'dean', '좋아하다', '더', '많다', '감성', '힙합'],
#   ['불후', '명곡', '전설', '노래', '특집', '김수철', '편', '곡'],
#   ['지브리', '애니메이션', '명곡', '피아노', '지브리', '콘서트'],
#   ['듣기', '해도', '전투력', '상승', '곡', '외힙', '위주'],
#   ['한번', '노래'],
#   ['집중', '작업', '도움', '음악'],
#   ['베이스', '사운드', '오지', '곡'],
#   ['Festival'],
#   ['인', '가구', '산다', '것'],
#   ['분위기', '있다', '비트', '음악', '하루', '만들기'],
#   ['감성', '자극', '음악', '모음'],
#   ['울', '잔잔하다', '노래'],
#   ['Disco', 'vibes'],
#   ['취향', 'j', 'pop'],
#   ['내', '좋아하다', '노래', '너', '좋아하다', '노래'],
#   ['카페', '새벽', '무드있는', '노래'],
#   ['새벽', '우울하다', '우울', '끝', '노래', 'vol'],
#   ['고백', '좋다', '날'],
#   ['무더위', '시원하다', '느낌'],
#   ['귓가', '자꾸', '맴도', '달달', '러브', '송'],
#   ['달콤', '달달', '로맨틱', '노래'],
#   ['비', '날', '우울하다', '마음', '노래', '모음'],
#   ['청량감', '여름', '저격', '댄스', '곡'],
#   ['꽃길', '입맞춤', '달콤하다', '분위기', '장르', '불문', '분위기'],
#   ['클럽', '일렉트로닉'],
#   ['그래미', '어워즈', '컨츄리', '가스펠', 'CCM', '부문', '후보', '곡'],
#   ['가슴', '뭉클'],
#   ['Standing', 'in', 'the', 'Shadows', 'of', 'Motown'],
#   ['금요일', '비', '다가', '날씨', '이상하다'],
#   ['응팔', 'ost', '모음', '집'],
#   ['거나', '좋아하다', '노래'],
#   ['곡', '없다', '것', '같다', '밤', '곡'],
#   ['Rock'],
#   ['리드미컬'],
#   ['목요일', '그냥', '싫다'],
#   [],
#   ['인생', '수', '있다', '시점', '널', '위로', '계속', '추가'],
#   ['커피', '조용하다', '듣기', '좋다', '노래'],
#   ['다양하다', '맛', '빨갛다', '고추', 'RHCP', '부'],
#   ['요즘', '푹', '곡'],
#   ['아련하다', '드라마', 'ost', '모음'],
#   ['사랑', '슬프다', '이별', '가슴'],
#   ['조금', '선선해지다', '밤', '듣기', '좋다', '노래'],
#   ['진토닉', '음악'],
#   ['holic'],
#   ['아침', '활', '위', '재즈'],
#   ['듣기', '좋다', '뉴에이지', '음악'],
#   ['번', '어도', '좋다', 'feat', 'CCM'],
#   ['이소라', '명곡', '집'],
#   ['좋다', '수', '이상', '곡'],
#   ['여름', '렉', '파도'],
#   ['ARIA', 'SinglesChart', 'Top', '호주', '차트'],
#   ['무덥다', '여름', '청량감', '더하다', '줄', '플레이', '리스트'],
#   ['새벽', '잠', '노래'],
#   ['오래되다', '드라마', 'ost'],
#   ['리드미컬하다', '느낌', '좋다', '느낌'],
#   ['나', '날'],
#   ['벅차오르다', '있다', '돌', '명곡'],
#   ['요요마', '곡'],
#   ['SG', '워', '너비', '재결'],
#   ['멜로디', '포레스트', '캠프', '주요', '라인업'],
#   ['루키', '행보', '기대', '신예', '아티스트'],
#   ['사랑', '노래'],
#   ['완전', '감동', '음악'],
#   ['봄'],
#   ['달달'],
#   ['사랑', '이', '있다'],
#   ['마약', '같다', '씨잼', '싱잉랩'],
#   ['혼자', '시간', '편안하다', '무드', '베드룸', '팝'],
#   ['가슴', '전율', '일렉트로니카', '세계'],
#   ['귀', '남자', 'R', 'B'],
#   ['힙잘알', '주차', '비프리'],
#   ['공부', '편안하다', '음악'],
#   ['혼자', '끄덕', '끄덕'],
#   ['따뜻하다', '봄', '녘', '힐링', '가득', '찬', '음색'],
#   ['가사', '꼭', '내', '얘기', '같다'],
#   ['아이돌', '명곡'],
#   ['태교', '음악', '사랑', '리아', '위해', '자장가', '음악'],
#   ['여름', '휴가', '차안', '듣기', '좋다', '노래'],
#   ['내', '고막', '여성', '솔로', '아티스트'],
#   [],
#   ['뉴에이지', '최신', '곡', '모음', '집'],
#   ['덥다', '여름', '그대', '시원하다', '노래'],
#   ['감성', '보컬', '알앤비', '좋다', '밤'],
#   ['diff', 'gig'],
#   ['진정하다', '울림'],
#   ['오늘', '서글프다'],
#   ['부드럽다', '뉴에이지'],
#   ['크리스마스', '아이돌', '겨울', '노래'],
#   ['내', '좋아하다', '래퍼', '지심'],
#   ['달달', '외로움', '같다', '인디음악'],
#   ['Nostalgia'],
#   ['마', '성의', '목소리', 'Zion', 'T', '수록', '곡'],
#   ['비', '커피', '추억', '잔잔하다', '노래'],
#   ['사랑', '관', '설레다', '가득하다', '피아노', '힐링', '음악'],
#   ['후', '입김', '시작', '겨울', '따스하다', '노래'],
#   ['한강', '릴', '렉스'],
#   ['Relaxed'],
#   ['크리스마스', '맞이'],
#   ['F', 'G', 'S'],
#   ['여유', '필요하다', '당신', '감미롭다', '재즈', '팝'],
#   ['FEMINISM'],
#   ['말듯', '네', '마음', '궁금하다'],
#   ['날', '야하다', '필', '청곡'],
#   ['인디음악', '소화', '가장', '쉽다', '방법'],
#   ['거장', '클린트', '이스트', '우드', '감독', '영화음악', '세계'],
#   ['이소라', '두번째', '프로포즈'],
#   ['볼', '빨갛다', '사춘기', '안지영', '생일'],
#   ['Classy', 'Music'],
#   ['무더위', '한번', 'COOL', 'LIST'],
#   ['내', '최애', '곡', '모음'],
#   ['명곡', '대신'],
#   ['모두', '알', '한번', '다시', '노래'],
#   ['곡', '모음'],
#   ['빌보드', '차트', '취향', '저격'],
#   ['파워', '풀', '가창력', '소유자', 'Kesha', '내한', '예상', '세트리스트'],
#   ['Van', 'Morrison', '이', '정도', '재즈', '충분하다'],
#   ['여름밤', '바람', '카페', '노래'],
#   ['록', '춤', '수', '있다'],
#   ['당신', '맘', '밤', '감성', '힙합'],
#   ['겁', '파이팅'],
#   ['국내', '힙', '스타일'],
#   ['고개', '듣기', '좋다', '노래'],
#   ['디제이', '플레이'],
#   ['Team', '워너', '에센셜', '제스', '글린'],
#   ['무도', '가요제', '후보', 'TOP'],
#   ['나', '중', '병', '락', '심취', 'r'],
#   ['중독', '강하다', '노래'],
#   ['연애', '세포', '자극', '달달', '남녀', '듀엣곡'],
#   ['랩', '도', '사람', '재즈'],
#   ['pop'],
#   ['퇴근길', '발라드', '취'],
#   ['사랑', '가득하다', '노래'],
#   ['락', '발라드'],
#   ['그루', '브', '넘치다', 'Jazz', 'Time'],
#   ['오래되다', '최신', '아니다', '사람', 'song', 'list'],
#   ['음악', '세계', '말'],
#   ['갈룡', '폴더'],
#   ['어쿠스틱', '노래'],
#   ['in', 'love'],
#   ['겨울', '봄', '사이'],
#   ['가을', '발라드', '감성', '샷추가', '음색', '시럽', '추가'],
#   ['시대', '차별', '없다', '인', '곡', '노래', '모음'],
#   ['네', '오기', '카페', '너', '일', '것'],
#   ['위', '노래', '선'],
#   ['사랑', '이름', '교집합'],
#   ['마음', '안정', '클래식'],
#   ['봄', '후'],
#   ['분위기', '노래'],
#   ['나', '감성', '음악'],
#   ['조용하다', '심연', '깊이', '여운'],
#   ['리메이크', '드라마'],
#   ['차', '타고'],
#   ['기억', '망각', '이동진', '꿈', '다방', 'MBC', '디'],
#   [],
#   ['정미', '애', '팬', '스밍', '용기', '초', '교류'],
#   ['비', '감성', '힙합', '드랍', '더', '비트'],
#   ['매장', '신나다', '음악'],
#   ['드라마', '속', '분위기', 'POP'],
#   ['덥다', '마음', '시원하다'],
#   ['이별', '어도'],
#   ['푸른', '바다', '남자', '이별이야기'],
#   ['특별하다', '주말', '특별하다', 'Classic'],
#   ['Dear', 'Your', 'Vibe', '음악', '오타쿠', '분위기', '오타쿠', '위'],
#   ['패밀리', '그룹'],
#   ['봄', '듣기', '좋다', '상큼', '달달', '경쾌', '발랄', '음악'],
#   ['무슨', '뜻', '숫자', '제목', '노래'],
#   ['안예은', 'BEST', '곡'],
#   ['멜로디', 'POP'],
#   ['두시'],
#   ['여름', '댄스', 'Ver'],
#   ['s', '이노', '그때', '노래'],
#   ['제이팝', '여왕', '하마', '사키', '아유미'],
#   ['클럽', '타', '자보', '아일랜드', '루루', '루', '진달래', '밴드', '문패', '트롤'],
#   ['신나다', '크리스마스'],
#   ['Billboard', 'TheHot', 'Top', '미국', '차트'],
#   ['가을', '머', '금은', '카페', '뮤직'],
#   ['R', 'B', '의', '새롭다', '물결', '얼터너티브', 'R', 'B'],
#   ['오지', '팝', '락각', 'vol', '겨울', '여행'],
#   ['서도', '볼', '수', '없다', '재즈', '모음'],
#   ['트와이스', '일본', '타이틀곡', '모음'],
#   ['Lofi', '외국', '힙합', 'update'],
#   ['Feel', 'so', 'good', '음악'],
#   ['얘기'],
#   ['베리', '베리', '해피', '메리', '크리스마스'],
#   ['태교', '좋다', '노래'],
#   ['노래'],
#   ['HEAD', 'CHARGE', 'SPIRITS', 'OF', 'ROCK'],
#   ['이', '노래', '가을', '가을', '시작', '노래'],
#   ['아버지', '어머니', '노래'],
#   ['나', '위로', '필요하다'],
#   ['달달', '재즈', '플레이', '리스트'],
#   ['So', 'Sweet', '감성', '힙합'],
#   ['향기', '가득하다', '매장', '위', '뉴에이지'],
#   ['신나다', '댄스', '곡'],
#   ['혼자', '시간', '따스하다', '팝', 'vol'],
#   ['이별', '후', '마음', '정리', '위', '감성', '음악'],
#   ['하루', '마무리', '편안하다', '곡'],
#   ['역대', '쇼미더머니', '음원', '모음'],
#   ['푸른', '바다', '전설', '도깨비', 'OST'],
#   ['설레임', '사운드'],
#   ['감각', '트렌디', '유니크', '노래'],
#   ['잔잔하다', '듣기', '좋다', '곡'],
#   ['s', '올드', '힙합', 'old', 'hiphop'],
#   ['가사', '은근'],
#   ['발라드', '모음'],
#   ['겨울', '감성', '진하다', '포근하다', '보이스', '라떼', '로맨틱', '멜로디'],
#   ['시원하다', '가을', '밤', '드라이브', '음악'],
#   ['I', 'ROBOT', '로보트', '주인공', '노래'],
#   ['새벽길', '잔잔하다', '감성', '리스트'],
#   ['OST', '아깝다', '명곡'],
#   ['걸그룹', '아이돌', '히트', '곡', '모음'],
#   ['차트', '국내', '차트'],
#   ['비투비', '각', '앨범', '별', '좋다', '수록', '곡'],
#   ['신디사이저', '베이비'],
#   ['날', '잔잔하다'],
#   ['날씨', '감성', '발라드', '따뜻하다'],
#   ['애니메이션', '명곡'],
#   ['학교', '길', '기분', '살랑', '살랑', '힙', '노래'],
#   [],
#   ['젊음', '가요제', '입상', '곡'],
#   ['드라이브', '여행', '듣기', '좋다', '상큼', '발랄', '신나다', '노래', '업뎃', '수정'],
#   ['유럽', '음악', '모음'],
#   ['밤', '나', '감성', '취향', '저격', '음악'],
#   ['내', '요즘', '노래'],
#   ['힘들다', '혼자', '듣기', '좋다', '음악'],
#   ['미국', '토종', '힙합', 'Thug', 'Life'],
#   ['도입', '부', 'POP'],
#   ['아무', '생각', '듣기', '좋다', '노래'],
#   ['슬프다', '힙합'],
#   ['마음', '맑다', '힐링', '뉴에이지'],
#   ['러브', '라인', '추리', '게임', '하트', '시그널', '시즌', 'BGM'],
#   ['한번', '팝송', '바로', '그거'],
#   ['국적', '느낌', '좋다', '음악'],
#   ['웨딩', '듣기', '해도', '결혼', '웨딩', '송'],
#   ['성인가요', 'Top'],
#   ['머릿속', '맴도', '멜로디', '중독', '짱'],
#   ['라이브', '아미', '주', '플레이', '리스트'],
#   ['나', '알', 'POP', 'R', 'B', '리스트'],
#   ['봄', '날', '멜랑콜리아', '색다르다', 'Pop', 'Rock'],
#   ['상큼', '상큼', '공감', '노래'],
#   ['멜론', 'DJ', '인기', '곡', 'TOP', '가요'],
#   ['렬루', 'r', 'b', '적', '곡'],
#   ['댄스'],
#   ['요즘', '곡'],
#   ['듣기', '좋다', '퓨전', '국악'],
#   ['가을', '하늘', '음악편지'],
#   ['심쿵', 'ost', '곡', '모음', '집'],
#   ['MET', 'LIFE'],
#   ['슬프다', '이별', 'R', 'B', '발라드', '노래', '곡'],
#   ['노래'],
#   ['UK', '싱글', '차트'],
#   ['잔차', '라이딩', '음악'],
#   ['나', 'BEST', '새봄', 'saevom'],
#   ['운동', '끝', '록', '음악', '상쾌하다', '홈트'],
#   ['클래식', '음악', '매력', '속'],
#   ['어쩌면', '우리', '첫', '클래식'],
#   ['라디오', '청취', '자', '사랑', '온', '대중가요'],
#   ['오페라', '아버지', '베르디', '명작'],
#   ['명곡', '리메이크'],
#   ['Shawn', 'Mendes', 'The', 'Tour', '첫', '내한', '예상', '세트리스트'],
#   ['miru'],
#   ['크리스마스', '노래', '퐁당', '보아'],
#   ['이렇다', '어쿠스틱', '분위기', '있다', '팝송', '추천'],
#   ['카톡', '프로필', '뮤직', '봄', '감성', '가득하다', '노래'],
#   ['나른하다', '시간', '달콤하다', '뉴에이지'],
#   ['FREE', '주말', 'STYLE', '뮤직', '시업', '뎃'],
#   ['혹시', '오늘', '하루', '우울하다'],
#   ['그냥', '좋다', '힙합', '팝'],
#   ['여름', '바다', 'SUMMER'],
#   ['따뜻하다', '카페', '재즈', '캐롤', '연주', '곡'],
#   ...])

# %%
data['tokens'] = PL_to_tokens

# %%
data
# Out:
#                                     title  \
# 0                                 여행같은 음악
# 1                                 요즘 너 말야
# 2                   편하게, 잔잔하게 들을 수 있는 곡.-
# 3                   크리스마스 분위기에 흠뻑 취하고 싶을때
# 4                                추억의 노래 ㅋ
# ...                                   ...
# 110526                      METAL E'SM #2
# 110527     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
# 110528              #1. 눈물이 앞을 가리는 나의_이야기
# 110529  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
# 110530                FAVORITE POPSONG!!!
#
#                                                     songs  \
# 0       [525514, 129701, 383374, 562083, 297861, 13954...
# 1       [432406, 675945, 497066, 120377, 389529, 24427...
# 2       [83116, 276692, 166267, 186301, 354465, 256598...
# 3       [394031, 195524, 540149, 287984, 440773, 10033...
# 4       [159327, 553610, 5130, 645103, 294435, 100657,...
# ...                                                   ...
# 110526  [429629, 441511, 612106, 516359, 691768, 38714...
# 110527  [321330, 216057, 534472, 240306, 331098, 23288...
# 110528  [50512, 249024, 250608, 371171, 229942, 694943...
# 110529  [533534, 608114, 343608, 417140, 609009, 30217...
# 110530  [26008, 456354, 324105, 89871, 135272, 143548,...
#
#                                         tokens
# 0                                 [여행, 같다, 음악]
# 1                                   [요즘, 너, 말]
# 2                        [편하다, 잔잔하다, 수, 있다, 곡]
# 3                         [크리스마스, 분위기, 흠뻑, 취하]
# 4                                     [추억, 노래]
# ...                                        ...
# 110526                          [METAL, E, SM]
# 110527  [빠르다, 리스너, 위, 따끈따끈하다, 최신, 인기, EDM, 모음]
# 110528                         [눈물, 앞, 나, 이야기]
# 110529         [퇴근, 버스, 편하다, 하루, 마무리, 좋다, POP]
# 110530                     [FAVORITE, POPSONG]
#
# [110531 rows x 3 columns]

# %%
entire_tokens = set({})
for tokens in PL_to_tokens:
    entire_tokens.update(tokens)

# %%
entire_tokens = list(entire_tokens)

# %%
len(entire_tokens)
# Out:
# 23499

# %%
token_to_PL = []
entire_songs = []
PL_cnt = []
PL_songs_cnt = []
cnt = 0

##################         주의 !!      #######################
#
# 아래는 잘 작동하는지 테스트하기위해 5개의 토큰만을 봅니다.
# 전체 데이터를 얻고 싶다면 주석 처리된 부분으로 바꿔주세요!


# for token in entire_tokens[:5]:
for token in entire_tokens:
    cnt += 1
    if cnt % 10 == 0: print(cnt)
    PL_list = []
    PL_songs = set({})
# for token in entire_tokens:
    for i in range(data.shape[0]):
        if token in data['tokens'].iloc[i]:
            PL_list.append(data['title'].iloc[i])
            PL_songs.update(data['songs'].iloc[i])
    token_to_PL.append(PL_list)
    entire_songs.append(PL_songs)
    PL_cnt.append(len(PL_list))
    PL_songs_cnt.append(len(PL_songs))

entire_songs = list(entire_songs)

# %%
len(entire_songs)
# Out:
# 5

# %%
token_DF = pd.DataFrame({'token' : entire_tokens[:len(token_to_PL)], 'playlist_title' : token_to_PL, 'songs' : entire_songs, 'PL_cnt' : PL_cnt, 'PL_songs_cnt' : PL_songs_cnt})

# %%
token_DF.iloc[0]['playlist_title']
# Out:
# ['영원한 재즈의 젊음, Roy Hargrove (1969~2018)']

# %%
token_DF = token_DF.sort_values(['PL_cnt'], ascending=[False])

# %%
token_DF = token_DF.reset_index(drop=True)

# %%
token_DF
# Out:
#       token                                     playlist_title  \
# 0        선수  [박태환선수가 듣는노래~, 국가대표 선수들 화이팅!!! (강렬한 록), 피겨선수들이...
# 1   오오오오오오오  [오오오오오오오, 노오력 노오오오오력 노오오오오오오오오력 노오오오오오오오오오오오력을...
# 2  Hargrove             [영원한 재즈의 젊음, Roy Hargrove (1969~2018)]
# 3  anyehrer                       [anyday~ anytime~ anyehrer~]
# 4     Proof                       [클럽 프리버드: 일본메탈밴드 My Proof공연]
#
#                                                songs  PL_cnt  PL_songs_cnt
# 0  {585216, 439301, 675334, 648202, 248332, 13839...      14           253
# 1  {152960, 127233, 122504, 393224, 169736, 15579...       2            54
# 2  {69090, 19683, 431271, 125576, 397066, 44075, ...       1            14
# 3  {217217, 339969, 528899, 681991, 21901, 15376,...       1            45
# 4  {144899, 399761, 376852, 652186, 592176, 60332...       1            23

# %%
# csv 파일로 저장
token_DF.to_csv("token_DF.csv")
